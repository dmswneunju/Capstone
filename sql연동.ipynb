# %%
import pymysql
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
#DB연결
con = pymysql.connect(host='database-1.c7rig0vgsupo.ap-northeast-2.rds.amazonaws.com', 
                      user='root', 
                      password='capstone',
                      db='capstone_project', 
                      charset='utf8', 
                      cursorclass=pymysql.cursors.DictCursor) # 한글처리 (charset = 'utf8')

# %%
# 디폴트 커서 생성
cur = con.cursor()
cur

# %%
query = "SELECT * FROM silver"
cur.execute(query)
# Out:
# 1372

# %%
result = cur.fetchall()
for row in result:
    print(row)
# Out:
# {'id': 1, 'name': '송추요양병원', 'location': '경기도 양주시 백석읍 기산리 317번지 5호', 'phonenumber': '', 'category': '침구과, 한방내과, 가정의학과, 내과', 'photo': '', 'open_time': '', 'xpos': '126.9407081275', 'ypos': '37.7767798594', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 25), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 25), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 2, 'name': '아시엘요양병원', 'location': '경기도 동두천시 상패동 201-19번지', 'phonenumber': '', 'category': '침구과, 한방재활의학과, 한방내과, 가정의학과, 비뇨기과, 피부과, 소아청소년과, 외과, 내과', 'photo': '', 'open_time': '', 'xpos': '127.0363051342', 'ypos': '37.9081637185', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 25), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 25), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 3, 'name': '삼성우리요양병원', 'location': '경기도 화성시 진안동 914-1번지 메인프라자 7층', 'phonenumber': '', 'category': '한방응급과, 침구과, 사상체질과, 한방재활의학과, 한방신경정신과, 한방안·이비인후·피부과, 한방소아과, 한방부인과, 한방내과, 재활의학과, 외과, 내과', 'photo': '', 'open_time': '', 'xpos': '127.0419699093', 'ypos': '37.2146333014', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 25), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 25), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 4, 'name': '화성해인요양병원', 'location': '경기도 화성시 매송면 원평리 50-13번지', 'phonenumber': '', 'category': '내과, 신경과, 소아청소년과, 안과, 이비인후과, 피부과, 재활의학과, 가정의학과, 한방내과, 한방부인과, 한방소아과, 한방안·이비인후·피부과, 한방신경정신과, 한방재활의학과, 사', 'photo': '', 'open_time': '', 'xpos': '126.9294065821', 'ypos': '37.2495333307', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 25), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 25), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 5, 'name': '의료법인다원의료재단 진접제일요양병원', 'location': '경기도 남양주시 진접읍 팔야리 728-8번지 진접제일요양병원', 'phonenumber': '', 'category': '내과, 신경과, 외과, 정형외과, 소아청소년과, 재활의학과, 한방내과', 'photo': '', 'open_time': '', 'xpos': '127.2047986019', 'ypos': '37.7461820710', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 25), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 25), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 6, 'name': '담우요양병원', 'location': '경기도 용인시 기흥구 보라동 580번지 3호', 'phonenumber': '', 'category': '내과, 신경과, 외과, 정형외과, 신경외과, 재활의학과, 가정의학과', 'photo': '', 'open_time': '', 'xpos': '127.1116554442', 'ypos': '37.2543726750', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 25), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 25), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 7, 'name': '의정부연세요양병원', 'location': '경기도 의정부시 의정부동 15번지 2호', 'phonenumber': '', 'category': '내과, 정신건강의학과, 재활의학과', 'photo': '', 'open_time': '', 'xpos': '127.0532305150', 'ypos': '37.7444431627', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 26), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 26), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 8, 'name': '(의)대선의료재단으뜸요양병원', 'location': '경기도 안산시 상록구 본오동 878번지 3호 지하1층 ~ 지상5층', 'phonenumber': '', 'category': '한방내과, 외과, 재활의학과', 'photo': '', 'open_time': '', 'xpos': '126.8611548247', 'ypos': '37.3015372551', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 26), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 26), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 9, 'name': '더드림의료소비자생활협동조합미래요양병원', 'location': '경기도 안산시 단원구 선부동 1070번지 18호 상록타운 401~406호', 'phonenumber': '', 'category': '신경외과, 이비인후과, 정형외과, 가정의학과, 외과, 내과, 침구과, 사상체질과, 한방재활의학과, 한방신경정신과, 한방안·이비인후·피부과, 한방부인과, 한방소아과, 한방내과', 'photo': '', 'open_time': '', 'xpos': '126.8093923381', 'ypos': '37.3366345730', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 26), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 26), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 10, 'name': '아이디어요양병원', 'location': '경기도 안산시 단원구 고잔동 642-4', 'phonenumber': '', 'category': '한방안·이비인후·피부과, 침구과, 한방소아과, 한방부인과, 한방재활의학과, 외과, 비뇨기과, 소아청소년과, 정형외과, 마취통증의학과, 신경외과, 재활의학과, 한방내과, 내과', 'photo': '', 'open_time': '', 'xpos': '126.8399339651', 'ypos': '37.3308327906', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 26), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 26), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 11, 'name': '베스트원요양병원', 'location': '경기도 안산시 상록구 본오동 720번지', 'phonenumber': '', 'category': '비뇨기과, 소아청소년과, 가정의학과, 내과, 정형외과, 침구과, 한방신경정신과, 한방부인과, 한방안·이비인후·피부과, 한방재활의학과, 사상체질과, 한방내과', 'photo': '', 'open_time': '', 'xpos': '126.8664715902', 'ypos': '37.2891628036', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 26), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 26), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 12, 'name': '새생명요양병원', 'location': '경기도 안산시 단원구 초지동 742-2번지 101-1,101-2,202,207호', 'phonenumber': '', 'category': '침구과, 사상체질과, 한방재활의학과, 한방신경정신과, 피부과, 한방안·이비인후·피부과, 한방소아과, 한방부인과, 한방내과, 가정의학과, 내과', 'photo': '', 'open_time': '', 'xpos': '126.8109164149', 'ypos': '37.3032474513', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 27), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 27), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 13, 'name': '행복한요양병원', 'location': '경기도 안산시 단원구 고잔동 704-2 201호', 'phonenumber': '', 'category': '', 'photo': '', 'open_time': '', 'xpos': '126.8276826053', 'ypos': '37.3135475014', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 27), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 27), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 14, 'name': '해오름요양병원', 'location': '경기도 안산시 단원구 선부동 1034번지 8호', 'phonenumber': '', 'category': '침구과, 한방신경정신과, 한방안·이비인후·피부과, 한방내과, 비뇨기과, 정형외과, 신경과, 외과, 내과', 'photo': '', 'open_time': '', 'xpos': '126.8076025850', 'ypos': '37.3422216424', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 27), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 27), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 15, 'name': '세명요양병원', 'location': '경기도 안산시 상록구 본오1동 904번지 13호 외 1필지', 'phonenumber': '', 'category': '침구과, 사상체질과, 한방재활의학과, 한방신경정신과, 한방안·이비인후·피부과, 한방소아과, 한방부인과, 한방내과, 정형외과, 내과', 'photo': '', 'open_time': '', 'xpos': '126.8629954359', 'ypos': '37.2906674851', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 27), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 27), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 16, 'name': '양주큰길요양병원', 'location': '경기도 양주시 광적면 가납리 495-2번지', 'phonenumber': '', 'category': '내과, 신경과, 외과, 정형외과, 신경외과, 산부인과, 재활의학과, 가정의학과, 한방내과', 'photo': '', 'open_time': '', 'xpos': '126.9955320618', 'ypos': '37.8101866274', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 27), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 27), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 17, 'name': '중앙효요양병원', 'location': '경기도 의정부시 의정부동 237번지 7호', 'phonenumber': '', 'category': '외과, 침구과', 'photo': '', 'open_time': '', 'xpos': '127.0454558175', 'ypos': '37.7462341073', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 27), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 27), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 18, 'name': '돌담요양병원', 'location': '경기도 양주시 백석읍 기산리 381-5번지', 'phonenumber': '', 'category': '침구과, 한방내과, 가정의학과, 마취통증의학과, 외과, 신경과, 내과', 'photo': '', 'open_time': '', 'xpos': '126.9378480251', 'ypos': '37.7720884312', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 27), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 27), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 19, 'name': '성남요양병원', 'location': '경기도 성남시 중원구 금광동 15번지 행림빌딩,지하1층,3~8층', 'phonenumber': '', 'category': '침구과, 한방재활의학과, 한방내과, 재활의학과, 가정의학과, 정형외과, 내과', 'photo': '', 'open_time': '', 'xpos': '127.1593990216', 'ypos': '37.4446578794', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 27), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 27), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 20, 'name': '라온힐요양병원', 'location': '경기도 성남시 중원구 여수동 202번지 지하3층 일부.2~10층', 'phonenumber': '', 'category': '내과, 신경과, 정형외과, 흉부외과, 안과, 재활의학과, 가정의학과', 'photo': '', 'open_time': '', 'xpos': '127.1268809796', 'ypos': '37.4182576584', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 27), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 27), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 21, 'name': '오크힐스분당요양병원', 'location': '경기도 성남시 중원구 도촌동 563번지 303,404,405,406,501호', 'phonenumber': '', 'category': '외과, 정형외과, 신경외과, 한방내과, 한방재활의학과, 침구과', 'photo': '', 'open_time': '', 'xpos': '127.1507518301', 'ypos': '37.4152028165', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 27), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 27), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 22, 'name': '좋은이웃요양병원', 'location': '경기 성남시 중원구 도촌로8번길 34', 'phonenumber': '', 'category': '재활의학과, 진단검사의학과, 영상의학과, 이비인후과, 소아청소년과, 정형외과, 외과, 신경과, 내과', 'photo': '', 'open_time': '', 'xpos': '127.1509523180', 'ypos': '37.4158200263', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 27), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 27), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 23, 'name': '성모요양병원', 'location': '경기도 성남시 분당구 야탑동 49, 51-1', 'phonenumber': '', 'category': '외과, 침구과, 정형외과, 신경외과, 신경과, 내과', 'photo': '', 'open_time': '', 'xpos': '127.1570941254', 'ypos': '37.4047113361', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 27), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 27), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 24, 'name': '은빛분당병원', 'location': '경기도 성남시 분당구 정자동 155-1번지 뉴본타워', 'phonenumber': '', 'category': '내과, 재활의학과', 'photo': '', 'open_time': '', 'xpos': '127.1063143634', 'ypos': '37.3639821050', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 28), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 28), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 25, 'name': '보바스기념병원', 'location': '경기도 성남시 분당구 금곡동 310번지 2호', 'phonenumber': '', 'category': '내과, 신경과, 재활의학과, 치과', 'photo': '', 'open_time': '', 'xpos': '127.1000250525', 'ypos': '37.3574349979', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 28), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 28), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 26, 'name': '새소망병원', 'location': '경기도 성남시수정구 수진2동 4553', 'phonenumber': '', 'category': '내과, 신경과, 가정의학과', 'photo': '', 'open_time': '', 'xpos': '127.1274354979', 'ypos': '37.4386304277', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 28), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 28), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 27, 'name': '로하스요양병원', 'location': '경기도 동두천시 송내동 673-4번지', 'phonenumber': '', 'category': '침구과, 한방내과, 가정의학과, 재활의학과, 이비인후과, 신경외과, 정형외과, 외과, 신경과, 내과', 'photo': '', 'open_time': '', 'xpos': '127.0533927972', 'ypos': '37.8815603500', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 28), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 28), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 28, 'name': '선재암요양병원', 'location': '경기도 광주시 도척면 추곡리 182번지 1호', 'phonenumber': '', 'category': '한방내과, 정형외과, 정신건강의학과, 신경과, 내과', 'photo': '', 'open_time': '', 'xpos': '127.2976196085', 'ypos': '37.2790752334', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 28), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 28), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 29, 'name': '성루카요양병원', 'location': '경기도 수원시 팔달구 인계동 942-4번지', 'phonenumber': '', 'category': '외과, 내과', 'photo': '', 'open_time': '', 'xpos': '127.0309147166', 'ypos': '37.2762726605', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 28), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 28), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 30, 'name': '의료법인 계요의료재단 계요노인전문병원', 'location': '경기도 의왕시 왕곡동 280번지 1호', 'phonenumber': '', 'category': '신경과, 가정의학과, 정신건강의학과, 내과', 'photo': '', 'open_time': '', 'xpos': '126.9813213825', 'ypos': '37.3479692759', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 28), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 28), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 31, 'name': '의정부요양병원', 'location': '경기도 의정부시 녹양동 321번지 3호', 'phonenumber': '', 'category': '내과, 신경과, 외과, 정형외과, 신경외과, 가정의학과, 한방내과, 한방부인과, 한방소아과, 한방안·이비인후·피부과, 한방신경정신과, 한방재활의학과, 침구과', 'photo': '', 'open_time': '', 'xpos': '127.0222282820', 'ypos': '37.7574267718', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 28), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 28), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 32, 'name': '동탄성모요양병원', 'location': '경기도 화성시 반송동 220-3번지 삼성미즈빌딩', 'phonenumber': '', 'category': '내과, 신경과, 외과, 산부인과', 'photo': '', 'open_time': '', 'xpos': '127.0735643111', 'ypos': '37.1941090849', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 28), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 28), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 33, 'name': '탑요양병원', 'location': '경기도 광명시 광명동 52번지 1호 지하1층~지상6층', 'phonenumber': '', 'category': '내과, 신경과, 외과, 정형외과, 신경외과, 흉부외과, 피부과, 재활의학과, 가정의학과, 응급의학과, 한방내과, 한방부인과, 한방소아과, 한방안·이비인후·피부과, 한방신경정신과, ', 'photo': '', 'open_time': '', 'xpos': '126.8559762675', 'ypos': '37.4850096640', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 28), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 28), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 34, 'name': '다온요양병원', 'location': '경기도 부천시 상동 235번지 1호 바로빌딩,바로빌딩,지하1층일부,2층,3층,6층', 'phonenumber': '', 'category': '내과, 신경과, 외과, 정형외과, 신경외과, 산부인과, 재활의학과, 가정의학과, 한방내과, 한방부인과, 침구과', 'photo': '', 'open_time': '', 'xpos': '126.7632065851', 'ypos': '37.4927419190', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 28), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 28), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 35, 'name': '의료법인양지의료재단양지요양병원', 'location': '경기도 이천시 호법면 매곡리 990-1번지', 'phonenumber': '', 'category': '한방재활의학과, 한방내과, 가정의학과, 외과, 신경과, 내과', 'photo': '', 'open_time': '', 'xpos': '127.3777674635', 'ypos': '37.1875841595', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 28), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 28), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 36, 'name': '우리요양병원', 'location': '경기도 이천시 백사면 조읍리 291번지 1호', 'phonenumber': '', 'category': '내과, 신경과, 외과, 정형외과, 재활의학과, 가정의학과, 한방내과, 한방재활의학과', 'photo': '', 'open_time': '', 'xpos': '127.4843447284', 'ypos': '37.3247947812', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 29), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 29), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 37, 'name': '서울라이즈요양병원', 'location': '경기도 구리시 수택동 515번지 53호 동진스카이빌딩 6층~10층', 'phonenumber': '', 'category': '신경과, 한방내과, 재활의학과, 내과', 'photo': '', 'open_time': '', 'xpos': '127.1437133448', 'ypos': '37.5981310767', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 29), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 29), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 38, 'name': '이담사랑요양병원', 'location': '경기도 동두천시 상패동 201-19', 'phonenumber': '', 'category': '한방내과, 비뇨기과, 재활의학과, 소아청소년과, 가정의학과, 이비인후과, 내과', 'photo': '', 'open_time': '', 'xpos': '127.0363051342', 'ypos': '37.9081637185', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 29), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 29), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 39, 'name': '늘푸른요양병원', 'location': '경기도 동두천시  695번지', 'phonenumber': '', 'category': '피부과, 성형외과, 재활의학과, 소아청소년과, 이비인후과, 신경과, 내과', 'photo': '', 'open_time': '', 'xpos': '127.0537918537', 'ypos': '37.8926929252', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 29), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 29), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 40, 'name': '동두천제일요양병원', 'location': '경기도 동두천시 광암동 481-3번지', 'phonenumber': '', 'category': '한방내과, 가정의학과, 재활의학과, 산부인과, 신경외과, 외과, 신경과, 내과', 'photo': '', 'open_time': '', 'xpos': '127.0826332478', 'ypos': '37.8949077610', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 29), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 29), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 41, 'name': '동광요양병원', 'location': '', 'phonenumber': '', 'category': '비뇨기과, 피부과, 산부인과, 소아청소년과, 가정의학과, 정형외과, 외과, 내과', 'photo': '', 'open_time': '', 'xpos': 'null', 'ypos': 'null', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 29), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 29), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 42, 'name': '서울요양병원', 'location': '경기도 동두천시 탑동동 651-2번지', 'phonenumber': '', 'category': '침구과, 한방재활의학과, 한방부인과, 한방내과, 가정의학과, 재활의학과, 산부인과, 신경외과, 정형외과, 신경과, 내과', 'photo': '', 'open_time': '', 'xpos': '127.1013878720', 'ypos': '37.8802184528', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 29), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 29), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 43, 'name': '로젠요양병원', 'location': '경기도 동두천시 생연동 307-13번지', 'phonenumber': '', 'category': '침구과, 한방내과, 가정의학과, 재활의학과, 비뇨의학과, 피부과, 소아청소년과, 신경외과, 정형외과, 외과, 정신건강의학과, 신경과, 내과', 'photo': '', 'open_time': '', 'xpos': '127.0627609235', 'ypos': '37.8992069249', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 29), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 29), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 44, 'name': '힐링탑요양병원', 'location': '경기도 동두천시 생연동 826번지 11호', 'phonenumber': '', 'category': '내과, 외과, 신경외과, 가정의학과, 한방내과, 침구과', 'photo': '', 'open_time': '', 'xpos': '127.0510558433', 'ypos': '37.9068599484', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 29), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 29), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 45, 'name': '우성요양병원', 'location': '경기도 안산시 단원구 고잔동 531번지 4호', 'phonenumber': '', 'category': '내과, 신경과, 외과, 정형외과, 신경외과, 마취통증의학과, 산부인과, 피부과, 비뇨의학과, 영상의학과, 진단검사의학과, 재활의학과, 가정의학과, 한방내과, 한방부인과, 한방소아과', 'photo': '', 'open_time': '', 'xpos': '126.8321400308', 'ypos': '37.3174036010', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 29), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 29), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 46, 'name': '힐링웰요양병원', 'location': '경기도 남양주시 호평동 642-3번지 ZENEW빌딩 4~5층', 'phonenumber': '', 'category': '내과, 신경과, 정신건강의학과, 외과, 정형외과, 신경외과, 흉부외과, 재활의학과, 가정의학과, 한방내과, 한방부인과, 한방안·이비인후·피부과, 한방신경정신과, 한방재활의학과, 사', 'photo': '', 'open_time': '', 'xpos': '127.2446247815', 'ypos': '37.6547176110', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 29), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 29), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 47, 'name': '마석기독요양병원', 'location': '경기도 남양주시 화도읍 창현리 493번지 6호', 'phonenumber': '', 'category': '내과, 소아청소년과, 피부과, 비뇨의학과, 재활의학과, 가정의학과, 한방내과, 한방부인과, 한방소아과, 한방안·이비인후·피부과, 한방신경정신과, 한방재활의학과, 사상체질과, 침구과', 'photo': '', 'open_time': '', 'xpos': '127.3049199266', 'ypos': '37.6526064167', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 29), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 29), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 48, 'name': '운정한강요양병원', 'location': '경기도 파주시 야당동 1074-1번지', 'phonenumber': '', 'category': '내과, 신경과, 외과, 정형외과, 신경외과, 피부과, 비뇨의학과, 가정의학과, 한방내과, 한방부인과, 한방안·이비인후·피부과, 한방신경정신과, 한방재활의학과, 사상체질과, 침구과', 'photo': '', 'open_time': '', 'xpos': '126.7601752407', 'ypos': '37.7157664259', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 30), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 30), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 49, 'name': '연세모아요양병원', 'location': '경기도 수원시 영통구 영통동 947-2번지', 'phonenumber': '', 'category': '가정의학과, 재활의학과, 소아청소년과, 산부인과', 'photo': '', 'open_time': '', 'xpos': '127.0805627445', 'ypos': '37.2671475731', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 30), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 30), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 50, 'name': '오산노인전문병원', 'location': '경기도 오산시 궐동 543번지', 'phonenumber': '', 'category': '가정의학과, 내과, 신경과', 'photo': '', 'open_time': '', 'xpos': '127.0437115644', 'ypos': '37.1649545092', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 30), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 30), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 51, 'name': '오산메디컬재활요양병원', 'location': '경기도 오산시 청학동 7번지 1호', 'phonenumber': '', 'category': '한방내과, 한방재활의학과, 내과, 재활의학과, 가정의학과', 'photo': '', 'open_time': '', 'xpos': '127.0648137727', 'ypos': '37.1540637028', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 30), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 30), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 52, 'name': '연제의료생활협동조합가평명인암노인전문병원', 'location': '경기도 가평군 상면 봉수리 49번지 4호', 'phonenumber': '', 'category': '한방내과, 가정의학과, 마취통증의학과, 신경과, 내과', 'photo': '', 'open_time': '', 'xpos': '127.3042092430', 'ypos': '37.8408474989', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 30), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 30), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 53, 'name': '경기도노인전문시흥병원', 'location': '경기도 시흥시 광석동 353번지 9호', 'phonenumber': '', 'category': '마취통증의학과, 영상의학과, 신경외과, 피부과, 산부인과, 정형외과, 안과, 이비인후과, 비뇨의학과, 재활의학과, 신경과, 한방재활의학과, 한방소아과, 한방부인과, 한방신경정신과,', 'photo': '', 'open_time': '', 'xpos': '126.8070960635', 'ypos': '37.3862686231', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 30), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 30), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 54, 'name': '포천새맘요양병원', 'location': '경기도 포천시 내촌면 소학리 314-8번지', 'phonenumber': '', 'category': '침구과, 한방재활의학과, 한방내과, 가정의학과, 외과, 신경과, 내과', 'photo': '', 'open_time': '', 'xpos': '127.2487443007', 'ypos': '37.7945497914', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 30), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 30), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 55, 'name': '국민의료생협 승리요양병원', 'location': '경기도 포천시 군내면 구읍리 9번지', 'phonenumber': '', 'category': '가정의학과, 피부과, 이비인후과, 안과, 내과', 'photo': '', 'open_time': '', 'xpos': '127.2299598273', 'ypos': '37.8843960964', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 30), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 30), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 56, 'name': '포천사랑요양병원', 'location': '경기도 포천시 소흘읍 송우리 726번지 76호', 'phonenumber': '', 'category': '재활의학과, 비뇨기과, 피부과, 신경외과, 정형외과, 외과, 정신건강의학과, 신경과, 내과', 'photo': '', 'open_time': '', 'xpos': '127.1406222303', 'ypos': '37.8303762534', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 30), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 30), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 57, 'name': '포천효성요양병원', 'location': '경기도 포천시 이동면 도평리 281번지 5호', 'phonenumber': '', 'category': '가정의학과, 비뇨기과, 정형외과, 피부과, 외과, 내과', 'photo': '', 'open_time': '', 'xpos': '127.3812262502', 'ypos': '38.0495647776', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 31), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 31), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 58, 'name': '메디힐포천요양병원', 'location': '경기도 포천시 신북면 기지리 961-1번지', 'phonenumber': '', 'category': '가정의학과, 재활의학과, 피부과, 정형외과, 외과, 신경과, 내과', 'photo': '', 'open_time': '', 'xpos': '127.2261906874', 'ypos': '37.9348602658', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 31), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 31), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 59, 'name': '후레쉬밸리요양병원', 'location': '경기도 포천시 화현면 화현리 729-3번지 지상1,2,3,4층', 'phonenumber': '', 'category': '침구과, 한방신경정신과, 한방부인과, 한방내과, 가정의학과', 'photo': '', 'open_time': '', 'xpos': '127.3097600079', 'ypos': '37.9010099320', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 31), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 31), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 60, 'name': '의료법인이정의료재단효사랑병원', 'location': '경기도 연천군 전곡읍 전곡리 235번지', 'phonenumber': '', 'category': '가정의학과, 산부인과, 정형외과, 외과, 내과', 'photo': '', 'open_time': '', 'xpos': '127.0690089157', 'ypos': '38.0174251575', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 31), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 31), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 61, 'name': '송추효자요양병원', 'location': '경기도 양주시 백석읍기산리368-3', 'phonenumber': '', 'category': '외과, 신경과, 내과', 'photo': '', 'open_time': '', 'xpos': '126.9377651076', 'ypos': '37.7710425112', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 31), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 31), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 62, 'name': '로뎀요양병원', 'location': '경기도 양주시 남면신암리153-8', 'phonenumber': '', 'category': '정신건강의학과, 신경과, 내과', 'photo': '', 'open_time': '', 'xpos': '126.9653693584', 'ypos': '37.9172633702', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 31), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 31), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 63, 'name': '자혜요양병원', 'location': '경기도 양주시 백석읍 기산리 381번지 3호', 'phonenumber': '', 'category': '정신건강의학과, 가정의학과, 흉부외과, 외과, 내과', 'photo': '', 'open_time': '', 'xpos': '126.9380148600', 'ypos': '37.7725488971', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 31), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 31), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 64, 'name': '양주효성요양병원', 'location': '경기도 양주시 백석읍 기산리 317번지 5호', 'phonenumber': '', 'category': '한방재활의학과, 침구과, 한방신경정신과, 한방내과, 피부과, 산부인과, 소아청소년과, 가정의학과, 내과', 'photo': '', 'open_time': '', 'xpos': '126.9407081275', 'ypos': '37.7767798594', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 31), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 31), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 65, 'name': '연세요양병원', 'location': '경기도 양주시 백석읍 기산리 368-3번지', 'phonenumber': '', 'category': '내과, 외과, 신경외과, 가정의학과, 한방내과, 침구과', 'photo': '', 'open_time': '', 'xpos': '126.9377651076', 'ypos': '37.7710425112', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 31), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 31), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 66, 'name': '예쓰요양병원', 'location': '경기도 양주시 덕정동 222-27번지', 'phonenumber': '', 'category': '한방응급과, 침구과, 사상체질과, 한방재활의학과, 한방신경정신과, 한방안·이비인후·피부과, 한방소아과, 한방부인과, 한방내과, 가정의학과, 정형외과, 외과, 신경과, 내과', 'photo': '', 'open_time': '', 'xpos': '127.0639294016', 'ypos': '37.8379947127', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 31), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 31), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 67, 'name': '한누리요양병원', 'location': '경기도 남양주시 화도읍 묵현리 408번지 1호', 'phonenumber': '', 'category': '한방내과, 가정의학과, 비뇨의학과, 피부과, 이비인후과, 신경과, 정형외과, 외과, 내과', 'photo': '', 'open_time': '', 'xpos': '127.2739390770', 'ypos': '37.6556787705', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 31), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 31), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 68, 'name': '햇살요양병원', 'location': '경기도 남양주시 호평동 23번지 21호', 'phonenumber': '', 'category': '외과, 침구과, 한방내과, 소아청소년과, 가정의학과, 재활의학과, 내과', 'photo': '', 'open_time': '', 'xpos': '127.2617483869', 'ypos': '37.6531851045', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 31), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 31), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 69, 'name': '경기도노인전문남양주병원', 'location': '경기도 남양주시 수동면 외방리 172-3외5', 'phonenumber': '', 'category': '가정의학과, 외과, 한방내과, 재활의학과, 신경과, 내과', 'photo': '', 'open_time': '', 'xpos': '127.3093143157', 'ypos': '37.7384027114', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 32), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 32), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 70, 'name': '효담요양병원', 'location': '경기도 남양주시 평내동 578번지 3호 메인프라자 9층', 'phonenumber': '', 'category': '비뇨기과, 피부과, 신경과, 가정의학과, 내과', 'photo': '', 'open_time': '', 'xpos': '127.2349761137', 'ypos': '37.6454215274', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 32), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 32), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 71, 'name': '남양주나무요양병원', 'location': '경기도 남양주시 평내동 578번지 3호 메인프라자 9층, 10층', 'phonenumber': '', 'category': '내과, 신경과, 외과, 정형외과, 마취통증의학과, 재활의학과, 가정의학과, 한방내과, 한방부인과, 한방소아과, 한방안·이비인후·피부과, 한방신경정신과, 사상체질과, 침구과', 'photo': '', 'open_time': '', 'xpos': '127.2349761137', 'ypos': '37.6454215274', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 32), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 32), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 72, 'name': '호평요양병원', 'location': '경기도 남양주시 호평동 641번지 1호 샤르망메디칼프라자, 7층 일부, 9층', 'phonenumber': '', 'category': '한방내과, 재활의학과, 마취통증의학과, 가정의학과', 'photo': '', 'open_time': '', 'xpos': '127.2445701661', 'ypos': '37.6541135945', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 32), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 32), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 73, 'name': '별내요양병원', 'location': '경기도 남양주시 별내동 1008번지 2호 별내동 JS타워 5층,6층', 'phonenumber': '', 'category': '침구과, 가정의학과, 정형외과, 신경외과, 내과, 재활의학과', 'photo': '', 'open_time': '', 'xpos': '127.1255475689', 'ypos': '37.6468825629', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 32), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 32), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 74, 'name': '한나의료소비자생활협동조합 수동아산요양병원', 'location': '경기도 남양주시 수동면 외방리 434번지 4호 1.2.3,4층', 'phonenumber': '', 'category': '한방응급과, 침구과, 사상체질과, 한방재활의학과, 한방신경정신과, 한방안·이비인후·피부과, 한방소아과, 한방부인과, 한방내과, 재활의학과, 신경과, 정형외과, 외과, 가정의학과, ', 'photo': '', 'open_time': '', 'xpos': '127.3038920341', 'ypos': '37.7373212338', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 32), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 32), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 75, 'name': '의료법인 소애의료재단 한울노인요양병원', 'location': '시흥시 정왕동 1861-7번지 A동 2층일부,3층일부', 'phonenumber': '', 'category': '내과, 재활의학과, 가정의학과, 침구과', 'photo': '', 'open_time': '', 'xpos': '126.7247122889', 'ypos': '37.3534522826', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 32), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 32), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 76, 'name': '의)엠케이의료재단효심요양병원', 'location': '경기도 안산시 상록구 사동 1400번지 9호 지상1층 ~ 지상4층', 'phonenumber': '', 'category': '한방내과, 가정의학과', 'photo': '', 'open_time': '', 'xpos': '126.8542112480', 'ypos': '37.2835530341', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 32), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 32), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 77, 'name': '라파엘요양병원', 'location': '경기도 안산시 단원구 초지동 690번지 6호', 'phonenumber': '', 'category': '한방내과, 이비인후과, 비뇨기과, 소아청소년과, 피부과, 정형외과, 내과, 외과, 신경외과', 'photo': '', 'open_time': '', 'xpos': '126.8203969229', 'ypos': '37.3155429976', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 32), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 32), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 78, 'name': '명성요양병원', 'location': '경기도 안산시 상록구 본오동 904번지 13호 지1~5층', 'phonenumber': '', 'category': '한방부인과, 침구과, 한방신경정신과, 사상체질과, 한방소아과, 한방내과, 가정의학과, 정형외과, 신경외과, 내과', 'photo': '', 'open_time': '', 'xpos': '126.8629954359', 'ypos': '37.2906674851', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 32), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 32), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 79, 'name': '안산제일노인전문병원', 'location': '경기도 안산시 단원구 선부동 1077번지 5호 2층, 3층, 4층(401, 402', 'phonenumber': '', 'category': '내과, 외과, 가정의학과, 한방내과', 'photo': '', 'open_time': '', 'xpos': '126.8120578172', 'ypos': '37.3327741917', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 32), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 32), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 80, 'name': '은요양병원', 'location': '경기도 안산시 상록구 사1동 1298번지 (2층~4층)', 'phonenumber': '', 'category': '침구과, 한방안·이비인후·피부과, 한방재활의학과, 한방신경정신과, 한방내과', 'photo': '', 'open_time': '', 'xpos': '126.8496557596', 'ypos': '37.2977429038', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 32), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 32), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 81, 'name': '의료법인새한빛의료재단 라이트요양병원', 'location': '경기도 안산시 단원구 고잔동 768번지 3호 드림프라자302호,302-1호,303', 'phonenumber': '', 'category': '내과, 외과, 정형외과, 신경외과, 소아청소년과, 이비인후과, 피부과, 영상의학과, 가정의학과', 'photo': '', 'open_time': '', 'xpos': '126.8324501276', 'ypos': '37.3116906103', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 33), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 33), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 82, 'name': '의료법인 효송의료재단 서안산노인전문병원', 'location': '경기도 안산시 단원구 초지동 742번지 프라임아트 201,209,210호, 4층 ', 'phonenumber': '', 'category': '한방소아과, 침구과, 한방부인과, 한방내과, 가정의학과, 신경외과, 피부과, 재활의학과, 정형외과, 신경과, 이비인후과, 외과, 내과', 'photo': '', 'open_time': '', 'xpos': '126.8098890738', 'ypos': '37.3033045615', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 33), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 33), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 83, 'name': '초지마루요양병원', 'location': '경기도 안산시 단원구  745번지  서해프라자 203,204,301,302,303', 'phonenumber': '', 'category': '정형외과, 신경외과, 가정의학과, 재활의학과, 정신건강의학과, 신경과, 외과, 내과, 침구과, 한방안·이비인후·피부과, 한방재활의학과, 한방신경정신과, 한방내과', 'photo': '', 'open_time': '', 'xpos': '126.8133164971', 'ypos': '37.3011341461', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 33), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 33), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 84, 'name': '세화요양병원', 'location': '경기도 안산시 상록구 이동 715번지 6,7층', 'phonenumber': '', 'category': '침구과, 한방재활의학과, 한방내과, 가정의학과, 재활의학과, 내과', 'photo': '', 'open_time': '', 'xpos': '126.8518153123', 'ypos': '37.3090490579', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 33), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 33), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 85, 'name': '초지요양병원', 'location': '경기도 안산시 단원구 초지동 745번지 서해프라자 203,204,301,302호', 'phonenumber': '', 'category': '한방신경정신과, 한방재활의학과, 침구과, 한방안·이비인후·피부과, 한방내과', 'photo': '', 'open_time': '', 'xpos': '126.8133164971', 'ypos': '37.3011341461', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 33), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 33), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 86, 'name': '의료법인호원의료재단호원요양병원', 'location': '경기도 안산시 상록구 월피동 508번지 1호 201,202,205,205-1,30', 'phonenumber': '', 'category': '신경과, 한방내과, 피부과, 재활의학과, 정형외과, 신경외과, 내과', 'photo': '', 'open_time': '', 'xpos': '126.8452906664', 'ypos': '37.3353153536', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 33), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 33), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 87, 'name': '휴웰요양병원', 'location': '경기도 안산시 단원구 고잔동 539번지 8호 1~8층', 'phonenumber': '', 'category': '외과, 한방내과, 가정의학과, 정형외과, 신경과, 재활의학과, 내과', 'photo': '', 'open_time': '', 'xpos': '126.8409665896', 'ypos': '37.3185798127', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 33), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 33), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 88, 'name': '안산시립노인전문병원', 'location': '경기도 안산시 상록구 사동 1586번지', 'phonenumber': '', 'category': '내과, 한방소아과, 침구과, 한방신경정신과, 한방부인과, 한방재활의학과, 사상체질과, 한방안·이비인후·피부과, 한방내과, 가정의학과, 재활의학과, 신경과', 'photo': '', 'open_time': '', 'xpos': '126.8461187218', 'ypos': '37.2996794131', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 33), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 33), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 89, 'name': '참사랑요양병원', 'location': '경기도 안산시 상록구 월피동 522번지 1층,2층,3층,4층', 'phonenumber': '', 'category': '가정의학과, 내과, 침구과, 사상체질과, 한방재활의학과, 한방신경정신과, 한방안·이비인후·피부과, 한방부인과, 한방소아과, 한방내과', 'photo': '', 'open_time': '', 'xpos': '126.8419564170', 'ypos': '37.3344946306', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 33), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 33), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 90, 'name': '안산그린요양병원', 'location': '경기도 안산시단원구 초지동 742번지 프라임아트 201,202,203,204,20', 'phonenumber': '', 'category': '한방내과, 재활의학과, 신경과, 가정의학과, 내과', 'photo': '', 'open_time': '', 'xpos': '126.8098890738', 'ypos': '37.3033045615', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 33), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 33), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 91, 'name': '아너스요양병원', 'location': '경기도 안산시 단원구  743-4번지 태영타운2층 209~217호, 3층 301호', 'phonenumber': '', 'category': '신경외과, 예방의학과, 응급의학과, 정신건강의학과, 외과, 한방내과, 신경과, 내과, 가정의학과, 재활의학과', 'photo': '', 'open_time': '', 'xpos': '126.8123003438', 'ypos': '37.3024442599', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 33), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 33), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 92, 'name': '한미재활요양병원', 'location': '경기도 안산시단원구 초지동 743-4 3층 301~307호', 'phonenumber': '', 'category': '신경외과, 정형외과, 내과, 한방내과, 재활의학과', 'photo': '', 'open_time': '', 'xpos': '126.8123003438', 'ypos': '37.3024442599', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 33), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 33), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 93, 'name': '호수요양병원', 'location': '경기도 안산시 단원구 고잔동 718번지 5호 대림프라자', 'phonenumber': '', 'category': '외과, 가정의학과, 한방내과, 한방부인과, 한방안·이비인후·피부과, 한방신경정신과, 한방재활의학과, 사상체질과, 침구과', 'photo': '', 'open_time': '', 'xpos': '126.8273242202', 'ypos': '37.3081732462', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 34), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 34), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 94, 'name': '드들요양병원', 'location': '경기도 안산시 상록구 본오동 948번지 11호 지2~7층(2층제외)', 'phonenumber': '', 'category': '소아청소년과, 가정의학과, 외과, 신경외과, 정형외과, 내과', 'photo': '', 'open_time': '', 'xpos': '126.8631379166', 'ypos': '37.2884869029', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 34), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 34), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 95, 'name': '안산청실재활요양병원', 'location': '경기도 안산시 단원구 초지동 742번지 201,203,204,205,209,210', 'phonenumber': '', 'category': '내과', 'photo': '', 'open_time': '', 'xpos': 'null', 'ypos': 'null', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 34), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 34), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 96, 'name': '정다운요양병원', 'location': '경기도 안산시 단원구 와동 800-17, 2~4층', 'phonenumber': '', 'category': '신경외과, 비뇨기과, 피부과, 정형외과, 외과, 내과', 'photo': '', 'open_time': '', 'xpos': '126.8188558398', 'ypos': '37.3449910913', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 34), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 34), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 97, 'name': '의료법인대선의료재단우리요양병원', 'location': '경기도 안산시 상록구 본오3동 873번지 3호', 'phonenumber': '', 'category': '침구과, 사상체질과, 한방신경정신과, 한방소아과, 한방부인과, 한방내과, 한방재활의학과, 정형외과, 재활의학과', 'photo': '', 'open_time': '', 'xpos': '126.8651053880', 'ypos': '37.3013782380', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 34), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 34), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 98, 'name': '베스트힐스요양병원', 'location': '경기도 안산시 상록구 사동 1497번지 3호', 'phonenumber': '', 'category': '한방내과, 가정의학과, 재활의학과, 외과, 정신건강의학과, 신경과, 내과', 'photo': '', 'open_time': '', 'xpos': '126.8441120087', 'ypos': '37.2812891131', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 34), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 34), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 99, 'name': '인성요양병원', 'location': '경기도 오산시 원동 761번지 16호', 'phonenumber': '', 'category': '치과, 침구과, 한방내과, 재활의학과, 정형외과, 외과, 내과', 'photo': '', 'open_time': '', 'xpos': '127.0710500179', 'ypos': '37.1465686517', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 34), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 34), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 100, 'name': '(의) 예림의료재단 청록요양병원', 'location': '전라북도 김제시 남북로 202, (요촌동)', 'phonenumber': '063-540-8500', 'category': '내과', 'photo': '', 'open_time': '', 'xpos': '126.8849407', 'ypos': '35.8020566', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 36), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 36), 'credit': Decimal('0.00'), 'province': '전북', 'doctorNo': 3, 'url': None, 'opendate': datetime.date(2008, 9, 1)}
# {'id': 101, 'name': '(의)밀성학원의료재단 성모요양병원', 'location': '경상남도 김해시 김해대로 2479-1, (삼정동)', 'phonenumber': '055-320-2080', 'category': '내과', 'photo': '', 'open_time': '', 'xpos': '128.8980324', 'ypos': '35.2281381', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 36), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 36), 'credit': Decimal('0.00'), 'province': '경남', 'doctorNo': 6, 'url': None, 'opendate': datetime.date(2010, 7, 27)}
# {'id': 102, 'name': '(의)수의료재단 서청솔요양병원', 'location': '경상남도 김해시 금관대로1084번길 15, (흥동)[*미고시]', 'phonenumber': '055-310-5500', 'category': '내과', 'photo': '', 'open_time': '', 'xpos': '128.8507902', 'ypos': '35.2240003', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 36), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 36), 'credit': Decimal('0.00'), 'province': '경남', 'doctorNo': 7, 'url': None, 'opendate': datetime.date(2019, 2, 7)}
# {'id': 103, 'name': '(의)영님의료재단 개금중앙요양병원', 'location': '부산광역시 부산진구 개금온정로 5, 지하1,지상3층 (개금동, 성원상떼뷰)', 'phonenumber': '051-582-7001', 'category': '내과', 'photo': '', 'open_time': '', 'xpos': '129.0247268', 'ypos': '35.1537540', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 36), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 36), 'credit': Decimal('0.00'), 'province': '부산', 'doctorNo': 6, 'url': None, 'opendate': datetime.date(2010, 8, 16)}
# {'id': 104, 'name': '(의)피터의료재단새소망요양병원', 'location': '부산광역시 기장군 기장읍 기장해안로 552, ()', 'phonenumber': '051-722-4848', 'category': '내과', 'photo': '', 'open_time': '', 'xpos': '129.2269050', 'ypos': '35.2228262', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 36), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 36), 'credit': Decimal('0.00'), 'province': '부산', 'doctorNo': 4, 'url': None, 'opendate': datetime.date(2005, 3, 17)}
# {'id': 105, 'name': '(의)현당의료재단 늘봄요양병원', 'location': '경기도 용인시 수지구 포은대로59번길 17, 광교복합의료센터,지하1층,1층일부,2', 'phonenumber': '031-659-7800', 'category': '내과', 'photo': '', 'open_time': '', 'xpos': '127.0658441', 'ypos': '37.3010717', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 36), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 36), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 6, 'url': None, 'opendate': datetime.date(2018, 4, 25)}
# {'id': 106, 'name': '(의)환명의료재단 경상남도립김해노인전문병원', 'location': '경상남도 김해시 김해대로 1814-39, (삼계동)', 'phonenumber': '055-330-2000', 'category': '내과', 'photo': '', 'open_time': '', 'xpos': '128.8610034', 'ypos': '35.2616213', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 36), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 36), 'credit': Decimal('0.00'), 'province': '경남', 'doctorNo': 6, 'url': None, 'opendate': datetime.date(2005, 7, 12)}
# {'id': 107, 'name': '(재)대성재단 대성제일요양병원', 'location': '경기도 부천시 부흥로373번길 18, (심곡동)', 'phonenumber': '032-610-1330', 'category': '내과', 'photo': '', 'open_time': '', 'xpos': '126.7838678', 'ypos': '37.4920227', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 36), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 36), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': datetime.date(2013, 7, 26)}
# {'id': 108, 'name': '365강서수요양병원', 'location': '서울특별시 강서구 양천로 35, 1~6층 (방화동, 강서성심병원)', 'phonenumber': '02-2663-0075', 'category': '내과', 'photo': '', 'open_time': '', 'xpos': '126.8077064', 'ypos': '37.5729765', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 36), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 36), 'credit': Decimal('0.00'), 'province': '서울', 'doctorNo': 4, 'url': None, 'opendate': datetime.date(2016, 9, 19)}
# {'id': 109, 'name': 'BB요양병원', 'location': '울산광역시 북구 염포로 353, (양정동)', 'phonenumber': '052-716-1020', 'category': '내과', 'photo': '', 'open_time': '', 'xpos': '129.3780269', 'ypos': '35.5593556', 'createdat': datetime.datetime(2023, 9, 18, 6, 40, 36), 'updatedat': datetime.datetime(2023, 9, 18, 6, 40, 36), 'credit': Decimal('0.00'), 'province': '울산', 'doctorNo': 4, 'url': None, 'opendate': datetime.date(2016, 11, 11)}
# ...
# {'id': 1336, 'name': '충북도립노인전문병원', 'location': '충청북도 청주시 서원구 청남로 1910-0, 충북도립노인전문병원', 'phonenumber': '043-287-7715', 'category': '산부인과', 'photo': '', 'open_time': '', 'xpos': '127.4804999', 'ypos': '36.6035913', 'createdat': datetime.datetime(2023, 9, 18, 6, 43, 34), 'updatedat': datetime.datetime(2023, 9, 18, 6, 43, 34), 'credit': Decimal('0.00'), 'province': '충북', 'doctorNo': 3, 'url': None, 'opendate': datetime.date(2001, 2, 12)}
# {'id': 1337, 'name': '의료법인청하의료재단 청하요양병원 인왕점', 'location': '경상북도 경주시 원화로 168,  (인왕동)', 'phonenumber': '054-746-0090', 'category': '안과', 'photo': '', 'open_time': '', 'xpos': '129.2202520', 'ypos': '35.8374288', 'createdat': datetime.datetime(2023, 9, 18, 6, 43, 57), 'updatedat': datetime.datetime(2023, 9, 18, 6, 43, 57), 'credit': Decimal('0.00'), 'province': '경북', 'doctorNo': 2, 'url': None, 'opendate': datetime.date(2007, 5, 30)}
# {'id': 1338, 'name': '에이치제이매그놀리아국제요양병원', 'location': '경기도 가평군 설악면 미사리로 267-177, ()', 'phonenumber': '031-589-4300', 'category': '이비인후과', 'photo': '', 'open_time': '', 'xpos': '127.5213618', 'ypos': '37.6911585', 'createdat': datetime.datetime(2023, 9, 18, 6, 44, 13), 'updatedat': datetime.datetime(2023, 9, 18, 6, 44, 13), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 3, 'url': None, 'opendate': datetime.date(2003, 5, 18)}
# {'id': 1339, 'name': '의료법인새림의료재단 압해생태요양병원', 'location': '전라남도 신안군 압해읍 추섬길 50-0,  0동 (의료법인새림압해생태요양병원)', 'phonenumber': '061-246-7200', 'category': '이비인후과', 'photo': '', 'open_time': '', 'xpos': '126.2873747', 'ypos': '34.8652522', 'createdat': datetime.datetime(2023, 9, 18, 6, 44, 15), 'updatedat': datetime.datetime(2023, 9, 18, 6, 44, 15), 'credit': Decimal('0.00'), 'province': '전남', 'doctorNo': 6, 'url': None, 'opendate': datetime.date(2018, 6, 25)}
# {'id': 1340, 'name': '화현요양병원', 'location': '경기도 포천시 화현면 화동로 517, 지하1,지상1~5층층', 'phonenumber': '031-532-0027', 'category': '피부과', 'photo': '', 'open_time': '', 'xpos': '127.3082230', 'ypos': '37.9128260', 'createdat': datetime.datetime(2023, 9, 19, 3, 58, 46), 'updatedat': datetime.datetime(2023, 9, 19, 3, 58, 46), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 2, 'url': None, 'opendate': datetime.date(2011, 11, 14)}
# {'id': 1341, 'name': '시립창원요양병원', 'location': '경상남도 창원시 의창구 북면 단내로 499-32, ()', 'phonenumber': '055-298-2442', 'category': '비뇨의학과', 'photo': '', 'open_time': '', 'xpos': '128.5743000', 'ypos': '35.3493546', 'createdat': datetime.datetime(2023, 9, 19, 3, 59, 10), 'updatedat': datetime.datetime(2023, 9, 19, 3, 59, 10), 'credit': Decimal('0.00'), 'province': '경남', 'doctorNo': 4, 'url': None, 'opendate': datetime.date(2002, 12, 13)}
# {'id': 1342, 'name': '여수노블요양병원', 'location': '전라남도 여수시 흥국로 40-0,  (학동)', 'phonenumber': '061-688-0000', 'category': '비뇨의학과', 'photo': '', 'open_time': '', 'xpos': '127.6667185', 'ypos': '34.7626936', 'createdat': datetime.datetime(2023, 9, 19, 3, 59, 10), 'updatedat': datetime.datetime(2023, 9, 19, 3, 59, 10), 'credit': Decimal('0.00'), 'province': '전남', 'doctorNo': 2, 'url': None, 'opendate': datetime.date(2009, 9, 30)}
# {'id': 1343, 'name': '의료법인연화의료재단부여요양병원', 'location': '충청남도 부여군 부여읍 삼충로 776, (부여읍)', 'phonenumber': '041-833-7200', 'category': '비뇨의학과', 'photo': '', 'open_time': '', 'xpos': '126.9873198', 'ypos': '36.3306047', 'createdat': datetime.datetime(2023, 9, 19, 3, 59, 11), 'updatedat': datetime.datetime(2023, 9, 19, 3, 59, 11), 'credit': Decimal('0.00'), 'province': '충남', 'doctorNo': 4, 'url': None, 'opendate': datetime.date(2011, 4, 4)}
# {'id': 1344, 'name': '여수시립요양병원', 'location': '전라남도 여수시 둔덕5길 29,  (둔덕동)', 'phonenumber': '061-653-9119', 'category': '방사선종양학과', 'photo': '', 'open_time': '', 'xpos': '127.6990750', 'ypos': '34.7645500', 'createdat': datetime.datetime(2023, 9, 19, 3, 59, 15), 'updatedat': datetime.datetime(2023, 9, 19, 3, 59, 15), 'credit': Decimal('0.00'), 'province': '전남', 'doctorNo': 4, 'url': None, 'opendate': datetime.date(2009, 5, 25)}
# {'id': 1345, 'name': '늘봄재활요양병원', 'location': '제주특별자치도 제주시 관덕로 30, (삼도이동)', 'phonenumber': '064-752-0022', 'category': '재활의학과', 'photo': '', 'open_time': '', 'xpos': '126.5224020', 'ypos': '33.5129871', 'createdat': datetime.datetime(2023, 9, 19, 3, 59, 51), 'updatedat': datetime.datetime(2023, 9, 19, 3, 59, 51), 'credit': Decimal('0.00'), 'province': '제주', 'doctorNo': 4, 'url': None, 'opendate': datetime.date(2007, 1, 17)}
# {'id': 1346, 'name': '동부센트럴요양병원', 'location': '서울특별시 강동구 올림픽로98길 8, (암사동, 동부센트럴요양병원)', 'phonenumber': '02-441-0011', 'category': '재활의학과', 'photo': '', 'open_time': '', 'xpos': '127.1284426', 'ypos': '37.5511272', 'createdat': datetime.datetime(2023, 9, 19, 3, 59, 52), 'updatedat': datetime.datetime(2023, 9, 19, 3, 59, 52), 'credit': Decimal('0.00'), 'province': '서울', 'doctorNo': 4, 'url': None, 'opendate': datetime.date(2010, 11, 17)}
# {'id': 1347, 'name': '서광주청연요양병원', 'location': '광주광역시 서구 개금길 61, 지하1~4층 (매월동, 서광주청연요양병원)', 'phonenumber': '062-714-3400', 'category': '재활의학과', 'photo': '', 'open_time': '', 'xpos': '126.8500027', 'ypos': '35.1228637', 'createdat': datetime.datetime(2023, 9, 19, 3, 59, 53), 'updatedat': datetime.datetime(2023, 9, 19, 3, 59, 53), 'credit': Decimal('0.00'), 'province': '광주', 'doctorNo': 10, 'url': None, 'opendate': datetime.date(2015, 9, 25)}
# {'id': 1348, 'name': '여수강남요양병원', 'location': '전라남도 여수시 진남로 15, (충무동)', 'phonenumber': '061-810-1004', 'category': '재활의학과', 'photo': '', 'open_time': '', 'xpos': '127.7300257', 'ypos': '34.7430532', 'createdat': datetime.datetime(2023, 9, 19, 3, 59, 56), 'updatedat': datetime.datetime(2023, 9, 19, 3, 59, 56), 'credit': Decimal('0.00'), 'province': '전남', 'doctorNo': 8, 'url': None, 'opendate': datetime.date(2016, 2, 23)}
# {'id': 1349, 'name': '나주광주요양병원', 'location': '전라남도 나주시 예향로 3782-0, (이창동)', 'phonenumber': '061-338-7500', 'category': '가정의학과', 'photo': '', 'open_time': '', 'xpos': '126.7114339', 'ypos': '34.9921190', 'createdat': datetime.datetime(2023, 9, 19, 4, 0, 16), 'updatedat': datetime.datetime(2023, 9, 19, 4, 0, 16), 'credit': Decimal('0.00'), 'province': '전남', 'doctorNo': 9, 'url': None, 'opendate': datetime.date(2018, 10, 11)}
# {'id': 1350, 'name': '무등요양병원', 'location': '광주광역시 남구 봉선1로 114, 2~6층, 지하1층 (봉선동)', 'phonenumber': '062-675-1111', 'category': '가정의학과', 'photo': '', 'open_time': '', 'xpos': '126.9175248', 'ypos': '35.1272868', 'createdat': datetime.datetime(2023, 9, 19, 4, 0, 18), 'updatedat': datetime.datetime(2023, 9, 19, 4, 0, 18), 'credit': Decimal('0.00'), 'province': '광주', 'doctorNo': 3, 'url': None, 'opendate': datetime.date(2019, 12, 27)}
# {'id': 1351, 'name': '무지개요양병원', 'location': '경기도 고양시 일산서구 덕이로 212, (덕이동, 백송프라자 3,4층 일부)', 'phonenumber': '031-916-1122', 'category': '가정의학과', 'photo': '', 'open_time': '', 'xpos': '126.7393345', 'ypos': '37.6966920', 'createdat': datetime.datetime(2023, 9, 19, 4, 0, 18), 'updatedat': datetime.datetime(2023, 9, 19, 4, 0, 18), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 8, 'url': None, 'opendate': datetime.date(2009, 3, 31)}
# {'id': 1352, 'name': '백담의료재단 한울요양병원', 'location': '전라남도 담양군 창평면 의병로 196, ()', 'phonenumber': '061-382-0800', 'category': '가정의학과', 'photo': '', 'open_time': '', 'xpos': '127.0211780', 'ypos': '35.2406280', 'createdat': datetime.datetime(2023, 9, 19, 4, 0, 18), 'updatedat': datetime.datetime(2023, 9, 19, 4, 0, 18), 'credit': Decimal('0.00'), 'province': '전남', 'doctorNo': 2, 'url': None, 'opendate': datetime.date(2014, 9, 24)}
# {'id': 1353, 'name': '부산시노인전문제1병원', 'location': '부산광역시 북구 함박봉로 98, (만덕동)', 'phonenumber': '051-342-7272', 'category': '가정의학과', 'photo': '', 'open_time': '', 'xpos': '129.0281998', 'ypos': '35.2061222', 'createdat': datetime.datetime(2023, 9, 19, 4, 0, 20), 'updatedat': datetime.datetime(2023, 9, 19, 4, 0, 20), 'credit': Decimal('0.00'), 'province': '부산', 'doctorNo': 5, 'url': None, 'opendate': datetime.date(2005, 1, 24)}
# {'id': 1354, 'name': '신안군공립요양병원', 'location': '전라남도 신안군 압해읍 구항길 92-50, ()', 'phonenumber': '061-260-2706', 'category': '가정의학과', 'photo': '', 'open_time': '', 'xpos': '126.3137863', 'ypos': '34.8532293', 'createdat': datetime.datetime(2023, 9, 19, 4, 0, 23), 'updatedat': datetime.datetime(2023, 9, 19, 4, 0, 23), 'credit': Decimal('0.00'), 'province': '전남', 'doctorNo': 2, 'url': None, 'opendate': datetime.date(2010, 7, 6)}
# {'id': 1355, 'name': '연세나을요양병원', 'location': '경기도 고양시 일산동구 장백로 174, 지하1층~지상10층 (장항동)', 'phonenumber': '031-949-4188', 'category': '가정의학과', 'photo': '', 'open_time': '', 'xpos': '126.7776369', 'ypos': '37.6504751', 'createdat': datetime.datetime(2023, 9, 19, 4, 0, 24), 'updatedat': datetime.datetime(2023, 9, 19, 4, 0, 24), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 3, 'url': None, 'opendate': datetime.date(2017, 9, 11)}
# {'id': 1356, 'name': '옥암힐요양병원', 'location': '전라남도 목포시 정의로 6-0,  (옥암동)', 'phonenumber': '061-281-7554', 'category': '가정의학과', 'photo': '', 'open_time': '', 'xpos': '126.4442814', 'ypos': '34.8122993', 'createdat': datetime.datetime(2023, 9, 19, 4, 0, 25), 'updatedat': datetime.datetime(2023, 9, 19, 4, 0, 25), 'credit': Decimal('0.00'), 'province': '전남', 'doctorNo': 3, 'url': None, 'opendate': datetime.date(2020, 9, 7)}
# {'id': 1357, 'name': '의료법인 건우의료재단 큰사랑요양병원', 'location': '충청북도 옥천군 옥천읍 중앙로 72, ()', 'phonenumber': '043-730-9000', 'category': '가정의학과', 'photo': '', 'open_time': '', 'xpos': '127.5709198', 'ypos': '36.3034536', 'createdat': datetime.datetime(2023, 9, 19, 4, 0, 26), 'updatedat': datetime.datetime(2023, 9, 19, 4, 0, 26), 'credit': Decimal('0.00'), 'province': '충북', 'doctorNo': 0, 'url': None, 'opendate': datetime.date(2008, 4, 14)}
# {'id': 1358, 'name': '의료법인평촌의료재단제주대림요양병원', 'location': '제주특별자치도 제주시 한림읍 한수풀로 58, ()', 'phonenumber': '064-796-0069', 'category': '가정의학과', 'photo': '', 'open_time': '', 'xpos': '126.2690698', 'ypos': '33.4181350', 'createdat': datetime.datetime(2023, 9, 19, 4, 0, 30), 'updatedat': datetime.datetime(2023, 9, 19, 4, 0, 30), 'credit': Decimal('0.00'), 'province': '제주', 'doctorNo': 4, 'url': None, 'opendate': datetime.date(2010, 10, 28)}
# {'id': 1359, 'name': '의료법인해인의료재단 해인요양병원', 'location': '경기도 안산시 상록구 샘골로 43, 1~5층 (본오동)', 'phonenumber': '031-416-1251', 'category': '가정의학과', 'photo': '', 'open_time': '', 'xpos': '126.8636375', 'ypos': '37.2878083', 'createdat': datetime.datetime(2023, 9, 19, 4, 0, 30), 'updatedat': datetime.datetime(2023, 9, 19, 4, 0, 30), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 3, 'url': None, 'opendate': datetime.date(2010, 8, 13)}
# {'id': 1360, 'name': '의료법인홍익의료재단파스카요양병원', 'location': '충청북도 청주시 청원구 내수읍 마산길 8-11, ()', 'phonenumber': '043-900-1004', 'category': '가정의학과', 'photo': '', 'open_time': '', 'xpos': '127.5388105', 'ypos': '36.7174013', 'createdat': datetime.datetime(2023, 9, 19, 4, 0, 30), 'updatedat': datetime.datetime(2023, 9, 19, 4, 0, 30), 'credit': Decimal('0.00'), 'province': '충북', 'doctorNo': 0, 'url': None, 'opendate': datetime.date(2018, 6, 1)}
# {'id': 1361, 'name': '이가양정요양병원', 'location': '광주광역시 광산구 하남울로 10, (하남동)', 'phonenumber': '062-675-7777', 'category': '가정의학과', 'photo': '', 'open_time': '', 'xpos': '126.8022406', 'ypos': '35.1811461', 'createdat': datetime.datetime(2023, 9, 19, 4, 0, 30), 'updatedat': datetime.datetime(2023, 9, 19, 4, 0, 30), 'credit': Decimal('0.00'), 'province': '광주', 'doctorNo': 2, 'url': None, 'opendate': datetime.date(2021, 3, 15)}
# {'id': 1362, 'name': '평심요양병원', 'location': '경상남도 양산시 하북면 신평로 37, 2~6층', 'phonenumber': '055-800-7090', 'category': '가정의학과', 'photo': '', 'open_time': '', 'xpos': '129.0864777', 'ypos': '35.4916235', 'createdat': datetime.datetime(2023, 9, 19, 4, 0, 33), 'updatedat': datetime.datetime(2023, 9, 19, 4, 0, 33), 'credit': Decimal('0.00'), 'province': '경남', 'doctorNo': 6, 'url': None, 'opendate': datetime.date(2016, 6, 21)}
# {'id': 1363, 'name': '현송요양병원', 'location': '전라남도 여수시 해산4길 37-0,  (해산동)', 'phonenumber': '061-691-1000', 'category': '가정의학과', 'photo': '', 'open_time': '', 'xpos': '127.6336470', 'ypos': '34.8020195', 'createdat': datetime.datetime(2023, 9, 19, 4, 0, 34), 'updatedat': datetime.datetime(2023, 9, 19, 4, 0, 34), 'credit': Decimal('0.00'), 'province': '전남', 'doctorNo': 3, 'url': None, 'opendate': datetime.date(2022, 2, 15)}
# {'id': 1364, 'name': '혜민요양병원', 'location': '강원특별자치도 평창군 봉평면 북길동길 17,', 'phonenumber': '033-336-0216', 'category': '가정의학과', 'photo': '', 'open_time': '', 'xpos': '128.3766131', 'ypos': '37.6230991', 'createdat': datetime.datetime(2023, 9, 19, 4, 0, 34), 'updatedat': datetime.datetime(2023, 9, 19, 4, 0, 34), 'credit': Decimal('0.00'), 'province': '강원', 'doctorNo': 2, 'url': None, 'opendate': datetime.date(2006, 5, 12)}
# {'id': 1365, 'name': '용인벧엘정신병원', 'location': '경기도 용인시 처인구 이동면 서리 160번지', 'phonenumber': '', 'category': '정신건강의학과, 가정의학과, 한방신경정신과, 한방재활의학과', 'photo': '', 'open_time': '', 'xpos': '127.1837318408', 'ypos': '37.1931473609', 'createdat': datetime.datetime(2023, 9, 24, 21, 1, 9), 'updatedat': datetime.datetime(2023, 9, 24, 21, 1, 9), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 1366, 'name': '세라요양병원', 'location': '경기도 부천시 원종동', 'phonenumber': '', 'category': '내과, 외과, 정형외과, 성형외과, 마취통증의학과, 산부인과, 소아청소년과, 안과, 이비인후과, 피부과, 비뇨기과, 영상의학과, 병리과, 재활의학과', 'photo': '', 'open_time': '', 'xpos': 'null', 'ypos': 'null', 'createdat': datetime.datetime(2023, 9, 24, 21, 1, 10), 'updatedat': datetime.datetime(2023, 9, 24, 21, 1, 10), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 1367, 'name': '동아효요양병원', 'location': '경기도 부천시 삼정동', 'phonenumber': '', 'category': '내과, 신경과, 외과, 산부인과, 재활의학과', 'photo': '', 'open_time': '', 'xpos': 'null', 'ypos': 'null', 'createdat': datetime.datetime(2023, 9, 24, 21, 1, 10), 'updatedat': datetime.datetime(2023, 9, 24, 21, 1, 10), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 1368, 'name': '광진요양병원', 'location': '경기도 부천시 상동 318-5번지 (1,5,8)층', 'phonenumber': '', 'category': '내과, 정형외과, 신경외과, 소아청소년과, 비뇨기과', 'photo': '', 'open_time': '', 'xpos': '126.7626817680', 'ypos': '37.4885924412', 'createdat': datetime.datetime(2023, 9, 24, 21, 1, 10), 'updatedat': datetime.datetime(2023, 9, 24, 21, 1, 10), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 1369, 'name': '혜강원요양병원', 'location': '경기도 부천시 중동 1123번지 2층호', 'phonenumber': '', 'category': '내과, 정형외과, 재활의학과, 가정의학과', 'photo': '', 'open_time': '', 'xpos': '126.7762258471', 'ypos': '37.4963647019', 'createdat': datetime.datetime(2023, 9, 24, 21, 1, 10), 'updatedat': datetime.datetime(2023, 9, 24, 21, 1, 10), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 1370, 'name': '사회복지법인 한마음복지협회 세라노인전문병원', 'location': '경기도 부천시 원종동 281-6번지', 'phonenumber': '', 'category': '내과, 신경과, 외과, 정형외과, 재활의학과', 'photo': '', 'open_time': '', 'xpos': '126.8051381684', 'ypos': '37.5223168572', 'createdat': datetime.datetime(2023, 9, 24, 21, 1, 10), 'updatedat': datetime.datetime(2023, 9, 24, 21, 1, 10), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 1371, 'name': '바오로요양병원', 'location': '경기도 부천시 심곡동 383번지 8호', 'phonenumber': '', 'category': '내과, 이비인후과, 피부과, 재활의학과, 가정의학과, 한방내과', 'photo': '', 'open_time': '', 'xpos': '126.7801943862', 'ypos': '37.4859873781', 'createdat': datetime.datetime(2023, 9, 24, 21, 1, 10), 'updatedat': datetime.datetime(2023, 9, 24, 21, 1, 10), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}
# {'id': 1372, 'name': '수동요양병원', 'location': '경기도 남양주시 수동면 운수리358-2 외2필지', 'phonenumber': '', 'category': '한방응급과, 침구과, 사상체질과, 한방재활의학과, 한방신경정신과, 한방안·이비인후·피부과, 한방소아과, 한방부인과, 한방내과, 신경과, 피부과, 내과, 가정의학과', 'photo': '', 'open_time': '', 'xpos': '127.3221335059', 'ypos': '37.7076603103', 'createdat': datetime.datetime(2023, 9, 24, 21, 1, 10), 'updatedat': datetime.datetime(2023, 9, 24, 21, 1, 10), 'credit': Decimal('0.00'), 'province': '경기', 'doctorNo': 0, 'url': None, 'opendate': None}

# %%
#데이터프레임으로 변환
result = pd.DataFrame(result)
result
# Out:
#         id                     name                           location  \
# 0        1                   송추요양병원           경기도 양주시 백석읍 기산리 317번지 5호
# 1        2                  아시엘요양병원              경기도 동두천시 상패동 201-19번지
# 2        3                 삼성우리요양병원       경기도 화성시 진안동 914-1번지 메인프라자 7층
# 3        4                 화성해인요양병원            경기도 화성시 매송면 원평리 50-13번지
# 4        5      의료법인다원의료재단 진접제일요양병원  경기도 남양주시 진접읍 팔야리 728-8번지 진접제일요양병원
# ...    ...                      ...                                ...
# 1367  1368                   광진요양병원        경기도 부천시 상동 318-5번지 (1,5,8)층
# 1368  1369                  혜강원요양병원              경기도 부천시 중동 1123번지 2층호
# 1369  1370  사회복지법인 한마음복지협회 세라노인전문병원                경기도 부천시 원종동 281-6번지
# 1370  1371                  바오로요양병원               경기도 부천시 심곡동 383번지 8호
# 1371  1372                   수동요양병원         경기도 남양주시 수동면 운수리358-2 외2필지
#
#      phonenumber                                           category photo  \
# 0                                              침구과, 한방내과, 가정의학과, 내과
# 1                 침구과, 한방재활의학과, 한방내과, 가정의학과, 비뇨기과, 피부과, 소아청소년과, ...
# 2                 한방응급과, 침구과, 사상체질과, 한방재활의학과, 한방신경정신과, 한방안·이비인후·...
# 3                 내과, 신경과, 소아청소년과, 안과, 이비인후과, 피부과, 재활의학과, 가정의학과,...
# 4                            내과, 신경과, 외과, 정형외과, 소아청소년과, 재활의학과, 한방내과
# ...          ...                                                ...   ...
# 1367                                   내과, 정형외과, 신경외과, 소아청소년과, 비뇨기과
# 1368                                         내과, 정형외과, 재활의학과, 가정의학과
# 1369                                       내과, 신경과, 외과, 정형외과, 재활의학과
# 1370                             내과, 이비인후과, 피부과, 재활의학과, 가정의학과, 한방내과
# 1371              한방응급과, 침구과, 사상체질과, 한방재활의학과, 한방신경정신과, 한방안·이비인후·...
#
#      open_time            xpos           ypos           createdat  \
# 0               126.9407081275  37.7767798594 2023-09-18 06:40:25
# 1               127.0363051342  37.9081637185 2023-09-18 06:40:25
# 2               127.0419699093  37.2146333014 2023-09-18 06:40:25
# 3               126.9294065821  37.2495333307 2023-09-18 06:40:25
# 4               127.2047986019  37.7461820710 2023-09-18 06:40:25
# ...        ...             ...            ...                 ...
# 1367            126.7626817680  37.4885924412 2023-09-24 21:01:10
# 1368            126.7762258471  37.4963647019 2023-09-24 21:01:10
# 1369            126.8051381684  37.5223168572 2023-09-24 21:01:10
# 1370            126.7801943862  37.4859873781 2023-09-24 21:01:10
# 1371            127.3221335059  37.7076603103 2023-09-24 21:01:10
#
#                updatedat credit province  doctorNo   url opendate
# 0    2023-09-18 06:40:25   0.00       경기         0  None     None
# 1    2023-09-18 06:40:25   0.00       경기         0  None     None
# 2    2023-09-18 06:40:25   0.00       경기         0  None     None
# 3    2023-09-18 06:40:25   0.00       경기         0  None     None
# 4    2023-09-18 06:40:25   0.00       경기         0  None     None
# ...                  ...    ...      ...       ...   ...      ...
# 1367 2023-09-24 21:01:10   0.00       경기         0  None     None
# 1368 2023-09-24 21:01:10   0.00       경기         0  None     None
# 1369 2023-09-24 21:01:10   0.00       경기         0  None     None
# 1370 2023-09-24 21:01:10   0.00       경기         0  None     None
# 1371 2023-09-24 21:01:10   0.00       경기         0  None     None
#
# [1372 rows x 16 columns]

# %% [markdown]
# ## 병원 진료과목, 병원 위치의 코사인 유사도로 병원 추천

# %%
# category 컬럼의 값을 쉼표로 분할하여 리스트로 변환
result['category'] = result['category'].str.split(', ')
# province 컬럼을 리스트로 변환
result['province'] = result['province'].apply(lambda x: [x])

# %%
# 병원 진료과목과 병원 위치를 토큰화
def create_soup(x):
    return ' '.join(x['category']) + ' ' + ' '.join(x['province'])

# %%
result['soup'] = result.apply(create_soup, axis=1)
result['soup']
# Out:
# 0                                    침구과 한방내과 가정의학과 내과 경기
# 1         침구과 한방재활의학과 한방내과 가정의학과 비뇨기과 피부과 소아청소년과 외과 내과 경기
# 2       한방응급과 침구과 사상체질과 한방재활의학과 한방신경정신과 한방안·이비인후·피부과 한...
# 3       내과 신경과 소아청소년과 안과 이비인후과 피부과 재활의학과 가정의학과 한방내과 한방...
# 4                     내과 신경과 외과 정형외과 소아청소년과 재활의학과 한방내과 경기
#                               ...
# 1367                          내과 정형외과 신경외과 소아청소년과 비뇨기과 경기
# 1368                               내과 정형외과 재활의학과 가정의학과 경기
# 1369                              내과 신경과 외과 정형외과 재활의학과 경기
# 1370                     내과 이비인후과 피부과 재활의학과 가정의학과 한방내과 경기
# 1371    한방응급과 침구과 사상체질과 한방재활의학과 한방신경정신과 한방안·이비인후·피부과 한...
# Name: soup, Length: 1372, dtype: object

# %%
result
# Out:
#         id                     name                           location  \
# 0        1                   송추요양병원           경기도 양주시 백석읍 기산리 317번지 5호
# 1        2                  아시엘요양병원              경기도 동두천시 상패동 201-19번지
# 2        3                 삼성우리요양병원       경기도 화성시 진안동 914-1번지 메인프라자 7층
# 3        4                 화성해인요양병원            경기도 화성시 매송면 원평리 50-13번지
# 4        5      의료법인다원의료재단 진접제일요양병원  경기도 남양주시 진접읍 팔야리 728-8번지 진접제일요양병원
# ...    ...                      ...                                ...
# 1367  1368                   광진요양병원        경기도 부천시 상동 318-5번지 (1,5,8)층
# 1368  1369                  혜강원요양병원              경기도 부천시 중동 1123번지 2층호
# 1369  1370  사회복지법인 한마음복지협회 세라노인전문병원                경기도 부천시 원종동 281-6번지
# 1370  1371                  바오로요양병원               경기도 부천시 심곡동 383번지 8호
# 1371  1372                   수동요양병원         경기도 남양주시 수동면 운수리358-2 외2필지
#
#      phonenumber                                           category photo  \
# 0                                            [침구과, 한방내과, 가정의학과, 내과]
# 1                 [침구과, 한방재활의학과, 한방내과, 가정의학과, 비뇨기과, 피부과, 소아청소년과,...
# 2                 [한방응급과, 침구과, 사상체질과, 한방재활의학과, 한방신경정신과, 한방안·이비인후...
# 3                 [내과, 신경과, 소아청소년과, 안과, 이비인후과, 피부과, 재활의학과, 가정의학과...
# 4                          [내과, 신경과, 외과, 정형외과, 소아청소년과, 재활의학과, 한방내과]
# ...          ...                                                ...   ...
# 1367                                 [내과, 정형외과, 신경외과, 소아청소년과, 비뇨기과]
# 1368                                       [내과, 정형외과, 재활의학과, 가정의학과]
# 1369                                     [내과, 신경과, 외과, 정형외과, 재활의학과]
# 1370                           [내과, 이비인후과, 피부과, 재활의학과, 가정의학과, 한방내과]
# 1371              [한방응급과, 침구과, 사상체질과, 한방재활의학과, 한방신경정신과, 한방안·이비인후...
#
#      open_time            xpos           ypos           createdat  \
# 0               126.9407081275  37.7767798594 2023-09-18 06:40:25
# 1               127.0363051342  37.9081637185 2023-09-18 06:40:25
# 2               127.0419699093  37.2146333014 2023-09-18 06:40:25
# 3               126.9294065821  37.2495333307 2023-09-18 06:40:25
# 4               127.2047986019  37.7461820710 2023-09-18 06:40:25
# ...        ...             ...            ...                 ...
# 1367            126.7626817680  37.4885924412 2023-09-24 21:01:10
# 1368            126.7762258471  37.4963647019 2023-09-24 21:01:10
# 1369            126.8051381684  37.5223168572 2023-09-24 21:01:10
# 1370            126.7801943862  37.4859873781 2023-09-24 21:01:10
# 1371            127.3221335059  37.7076603103 2023-09-24 21:01:10
#
#                updatedat credit province  doctorNo   url opendate  \
# 0    2023-09-18 06:40:25   0.00     [경기]         0  None     None
# 1    2023-09-18 06:40:25   0.00     [경기]         0  None     None
# 2    2023-09-18 06:40:25   0.00     [경기]         0  None     None
# 3    2023-09-18 06:40:25   0.00     [경기]         0  None     None
# 4    2023-09-18 06:40:25   0.00     [경기]         0  None     None
# ...                  ...    ...      ...       ...   ...      ...
# 1367 2023-09-24 21:01:10   0.00     [경기]         0  None     None
# 1368 2023-09-24 21:01:10   0.00     [경기]         0  None     None
# 1369 2023-09-24 21:01:10   0.00     [경기]         0  None     None
# 1370 2023-09-24 21:01:10   0.00     [경기]         0  None     None
# 1371 2023-09-24 21:01:10   0.00     [경기]         0  None     None
#
#                                                    soup
# 0                                  침구과 한방내과 가정의학과 내과 경기
# 1       침구과 한방재활의학과 한방내과 가정의학과 비뇨기과 피부과 소아청소년과 외과 내과 경기
# 2     한방응급과 침구과 사상체질과 한방재활의학과 한방신경정신과 한방안·이비인후·피부과 한...
# 3     내과 신경과 소아청소년과 안과 이비인후과 피부과 재활의학과 가정의학과 한방내과 한방...
# 4                   내과 신경과 외과 정형외과 소아청소년과 재활의학과 한방내과 경기
# ...                                                 ...
# 1367                        내과 정형외과 신경외과 소아청소년과 비뇨기과 경기
# 1368                             내과 정형외과 재활의학과 가정의학과 경기
# 1369                            내과 신경과 외과 정형외과 재활의학과 경기
# 1370                   내과 이비인후과 피부과 재활의학과 가정의학과 한방내과 경기
# 1371  한방응급과 침구과 사상체질과 한방재활의학과 한방신경정신과 한방안·이비인후·피부과 한...
#
# [1372 rows x 17 columns]

# %%
count = CountVectorizer()
count_matrix = count.fit_transform(result['soup'])
count_matrix #1372개의 rwo에 대해서 52개의 단어를 가지는 matirx 생성, 그 중 0이아닌 유효한 데이터가 3487개가 있다.
# Out:
# <1372x52 sparse matrix of type '<class 'numpy.int64'>'
# 	with 3487 stored elements in Compressed Sparse Row format>

# %%
cosine_sim2 = cosine_similarity(count_matrix, count_matrix)
cosine_sim2
# Out:
# array([[1.        , 0.70710678, 0.46188022, ..., 0.36514837, 0.6761234 ,
#         0.52704628],
#        [0.70710678, 1.        , 0.57154761, ..., 0.38729833, 0.5976143 ,
#         0.59628479],
#        [0.46188022, 0.57154761, 1.        , ..., 0.42163702, 0.48795004,
#         0.85201287],
#        ...,
#        [0.36514837, 0.38729833, 0.42163702, ..., 1.        , 0.46291005,
#         0.28867513],
#        [0.6761234 , 0.5976143 , 0.48795004, ..., 0.46291005, 1.        ,
#         0.53452248],
#        [0.52704628, 0.59628479, 0.85201287, ..., 0.28867513, 0.53452248,
#         1.        ]])

# %%
#병원 이름 중복 제거
indices = pd.Series(result.index, index=result['name']).drop_duplicates()
indices
# Out:
# name
# 송추요양병원                        0
# 아시엘요양병원                       1
# 삼성우리요양병원                      2
# 화성해인요양병원                      3
# 의료법인다원의료재단 진접제일요양병원           4
#                            ...
# 광진요양병원                     1367
# 혜강원요양병원                    1368
# 사회복지법인 한마음복지협회 세라노인전문병원    1369
# 바오로요양병원                    1370
# 수동요양병원                     1371
# Length: 1372, dtype: int64

# %%
# 병원의 인덱스 값 추출
indices['삼성우리요양병원']
# Out:
# 2

# %%
# 병원이름을 입력받으면 코사인 유사도를 통해서 가장 유사도가 높은 상위 10개의 병원 리스트 반환
def get_recommendations(name, cosine_sim=cosine_sim2):
    # 병원이름을 통해서 전체 데이터 기준 그 영화의 index 값을 얻기
    idx = indices[name]
    
    # 코사인 유사도 매트릭스 (cosine_sim) 에서 idx 에 해당하는 데이터를 (idx, 유사도) 형태로 얻기
    sim_scores = list(enumerate(cosine_sim[idx]))
    
    # 코사인 유사도 기준으로 내림차순 정렬
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    
    # 자기 자신을 제외한 10개의 추천 병원을 슬라이싱
    sim_scores = sim_scores[1:11]
    
    # 추천 병원 목록 10개의 인덱스 정보 추출
    hospital_indices = [i[0] for i in sim_scores]
    
    # 인덱스 정보를 통해 병원 이름 추출
    return result['name'].iloc[hospital_indices]

# %%
original_hospital = '송추요양병원'

# %%
recommend_hopitals10 = get_recommendations(original_hospital, cosine_sim2)

# %%
recommend_hopitals10
# Out:
# 43                 힐링탑요양병원
# 64                  연세요양병원
# 83                  세화요양병원
# 74    의료법인 소애의료재단 한울노인요양병원
# 78              안산제일노인전문병원
# 17                  돌담요양병원
# 18                  성남요양병원
# 53                포천새맘요양병원
# 67                  햇살요양병원
# 75         의)엠케이의료재단효심요양병원
# Name: name, dtype: object

# %%
desired_row = result[result['name'] == '송추요양병원']
desired_row
# Out:
#    id    name                  location phonenumber                category  \
# 0   1  송추요양병원  경기도 양주시 백석읍 기산리 317번지 5호              [침구과, 한방내과, 가정의학과, 내과]
#
#   photo open_time            xpos           ypos           createdat  \
# 0                  126.9407081275  37.7767798594 2023-09-18 06:40:25
#
#             updatedat credit province  doctorNo   url opendate  \
# 0 2023-09-18 06:40:25   0.00     [경기]         0  None     None
#
#                    soup
# 0  침구과 한방내과 가정의학과 내과 경기

# %%
desired_row2 = result[result['name'] == '힐링탑요양병원']
desired_row2
# Out:
#     id     name                location phonenumber  \
# 43  44  힐링탑요양병원  경기도 동두천시 생연동 826번지 11호
#
#                             category photo open_time            xpos  \
# 43  [내과, 외과, 신경외과, 가정의학과, 한방내과, 침구과]                  127.0510558433
#
#              ypos           createdat           updatedat credit province  \
# 43  37.9068599484 2023-09-18 06:40:29 2023-09-18 06:40:29   0.00     [경기]
#
#     doctorNo   url opendate                          soup
# 43         0  None     None  내과 외과 신경외과 가정의학과 한방내과 침구과 경기

# %%
desired_row2 = result[result['name'] == '의)엠케이의료재단효심요양병원']
desired_row2
# Out:
#     id             name                              location phonenumber  \
# 75  76  의)엠케이의료재단효심요양병원  경기도 안산시 상록구 사동 1400번지 9호 지상1층 ~ 지상4층
#
#          category photo open_time            xpos           ypos  \
# 75  [한방내과, 가정의학과]                  126.8542112480  37.2835530341
#
#              createdat           updatedat credit province  doctorNo   url  \
# 75 2023-09-18 06:40:32 2023-09-18 06:40:32   0.00     [경기]         0  None
#
#    opendate           soup
# 75     None  한방내과 가정의학과 경기

# %% [markdown]
# ### 병원 db로 보내기

# %% [markdown]
# # 테이블 생성 쿼리
# create_table_query = """
# CREATE TABLE IF NOT EXISTS recommended_hospitals (
#     id INT AUTO_INCREMENT PRIMARY KEY,
#     original_hospital VARCHAR(255) NOT NULL,
#     recommended_hospital VARCHAR(255) NOT NULL,
#     similarity FLOAT
# )
# """
#
# # 테이블 생성
# cur.execute(create_table_query)

# %%
# 기존 추천 결과 리스트 전부 삭제 (선택 사항)
delete_query = "DELETE FROM recommended_hospitals"
cur.execute(delete_query)
con.commit()

# %%
# 새로운 추천 결과 삽입
insert_query = "INSERT INTO recommended_hospitals (original_hospital, recommended_hospital) VALUES (%s, %s)"
for recommended_hospital in recommend_hopitals10:
    cur.execute(insert_query, (original_hospital, recommended_hospital))
con.commit()

# %%
input_q = "SELECT * FROM capstone_project.recommended_hospitals"
cur.execute(input_q)
# Out:
# ---------------------------------------------------------------------------
# ConnectionAbortedError                    Traceback (most recent call last)
# File c:\Users\leeej\miniconda3\envs\python38\lib\site-packages\pymysql\connections.py:756, in Connection._write_bytes(self, data)
#     755 try:
# --> 756     self._sock.sendall(data)
#     757 except IOError as e:
#
# ConnectionAbortedError: [WinError 10053] 현재 연결은 사용자의 호스트 시스템의 소프트웨어의 의해 중단되었습니다
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# c:\Users\leeej\capstone\sql연동.ipynb 셀 34 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/leeej/capstone/sql%EC%97%B0%EB%8F%99.ipynb#Y140sZmlsZQ%3D%3D?line=0'>1</a> input_q = "SELECT * FROM capstone_project.recommended_hospitals"
# ----> <a href='vscode-notebook-cell:/c%3A/Users/leeej/capstone/sql%EC%97%B0%EB%8F%99.ipynb#Y140sZmlsZQ%3D%3D?line=1'>2</a> cur.execute(input_q)
#
# File c:\Users\leeej\miniconda3\envs\python38\lib\site-packages\pymysql\cursors.py:148, in Cursor.execute(self, query, args)
#     144     pass
#     146 query = self.mogrify(query, args)
# --> 148 result = self._query(query)
#     149 self._executed = query
#     150 return result
#
# File c:\Users\leeej\miniconda3\envs\python38\lib\site-packages\pymysql\cursors.py:310, in Cursor._query(self, q)
#     308 self._last_executed = q
#     309 self._clear_result()
# --> 310 conn.query(q)
#     311 self._do_get_result()
#     312 return self.rowcount
#
# File c:\Users\leeej\miniconda3\envs\python38\lib\site-packages\pymysql\connections.py:547, in Connection.query(self, sql, unbuffered)
#     545 if isinstance(sql, str):
#     546     sql = sql.encode(self.encoding, "surrogateescape")
# --> 547 self._execute_command(COMMAND.COM_QUERY, sql)
#     548 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549 return self._affected_rows
#
# File c:\Users\leeej\miniconda3\envs\python38\lib\site-packages\pymysql\connections.py:814, in Connection._execute_command(self, command, sql)
#     812 prelude = struct.pack("<iB", packet_size, command)
#     813 packet = prelude + sql[: packet_size - 1]
# --> 814 self._write_bytes(packet)
#     815 if DEBUG:
#     816     dump_packet(packet)
#
# File c:\Users\leeej\miniconda3\envs\python38\lib\site-packages\pymysql\connections.py:759, in Connection._write_bytes(self, data)
#     757 except IOError as e:
#     758     self._force_close()
# --> 759     raise err.OperationalError(
#     760         CR.CR_SERVER_GONE_ERROR, "MySQL server has gone away (%r)" % (e,)
#     761     )
#
# OperationalError: (2006, "MySQL server has gone away (ConnectionAbortedError(10053, '현재 연결은 사용자의 호스트 시스템의 소프트웨어의 의해 중단되었습니다', None, 10053, None))")

# %%
# 연결 종료
cur.close()
con.close()
