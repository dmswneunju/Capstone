# %%
import requests
import pprint
import json

# url 입력
url = 'https://apis.data.go.kr/B551182/hospInfoServicev2/getHospBasisList?serviceKey=jxwOJdF3W7dg4P7he9%2F2hwaPwgDszkbSReBLZF6tdG55G%2BcZQflK6SsRbR%2BioSWMeADf0A3vKKiSAm3JgWUU4A%3D%3D&pageNo=1&numOfRows=100&sidoCd=310000&zipCd=2040&clCd=28&_type=json'
# url 불러오기
response = requests.get(url)

#데이터 값 출력해보기
contents = response.text

# %%
response = requests.get(url)
contents = response.text
print(contents)
# Out:
# {"response":{"header":{"resultCode":"00","resultMsg":"NORMAL SERVICE."},"body":{"items":{"item":[{"addr":"경기도 안산시 상록구 용신로 352, (본오동, 목화웨딩홀)","clCd":28,"clCdNm":"요양병원","cmdcGdrCnt":0,"cmdcIntnCnt":0,"cmdcResdntCnt":0,"cmdcSdrCnt":0,"detyGdrCnt":0,"detyIntnCnt":0,"detyResdntCnt":0,"detySdrCnt":0,"drTotCnt":0,"estbDd":20060310,"mdeptGdrCnt":0,"mdeptIntnCnt":0,"mdeptResdntCnt":0,"mdeptSdrCnt":0,"pnursCnt":0,"postNo":15537,"sgguCd":311102,"sgguCdNm":"안산상록구","sidoCd":310000,"sidoCdNm":"경기","telno":"031-363-5200","XPos":126.8611506,"YPos":37.3015419,"yadmNm":"(의)대선의료재단으뜸요양병원","ykiho":"JDQ4MTYyMiM1MSMkMSMkMCMkOTkkNTgxMzUxIzIxIyQyIyQ5IyQwMCQyNjEyMjIjODEjJDEjJDYjJDgz"},{"addr":"경기도 용인시 수지구 포은대로59번길 17, 광교복합의료센터,지하1층,1층일부,2층~4층,6층 (상현동)","clCd":28,"clCdNm":"요양병원","cmdcGdrCnt":1,"cmdcIntnCnt":0,"cmdcResdntCnt":0,"cmdcSdrCnt":1,"detyGdrCnt":0,"detyIntnCnt":0,"detyResdntCnt":0,"detySdrCnt":0,"drTotCnt":6,"estbDd":20180425,"mdeptGdrCnt":0,"mdeptIntnCnt":0,"mdeptResdntCnt":0,"mdeptSdrCnt":4,"pnursCn
# ...

# %%
pp = pprint.PrettyPrinter(indent=4)
print(pp.pprint(contents))
# Out:
# ('{"response":{"header":{"resultCode":"00","resultMsg":"NORMAL '
#  'SERVICE."},"body":{"items":{"item":[{"addr":"경기도 안산시 상록구 용신로 352, (본오동, '
#  '목화웨딩홀)","clCd":28,"clCdNm":"요양병원","cmdcGdrCnt":0,"cmdcIntnCnt":0,"cmdcResdntCnt":0,"cmdcSdrCnt":0,"detyGdrCnt":0,"detyIntnCnt":0,"detyResdntCnt":0,"detySdrCnt":0,"drTotCnt":0,"estbDd":20060310,"mdeptGdrCnt":0,"mdeptIntnCnt":0,"mdeptResdntCnt":0,"mdeptSdrCnt":0,"pnursCnt":0,"postNo":15537,"sgguCd":311102,"sgguCdNm":"안산상록구","sidoCd":310000,"sidoCdNm":"경기","telno":"031-363-5200","XPos":126.8611506,"YPos":37.3015419,"yadmNm":"(의)대선의료재단으뜸요양병원","ykiho":"JDQ4MTYyMiM1MSMkMSMkMCMkOTkkNTgxMzUxIzIxIyQyIyQ5IyQwMCQyNjEyMjIjODEjJDEjJDYjJDgz"},{"addr":"경기도 '
#  '용인시 수지구 포은대로59번길 17, 광교복합의료센터,지하1층,1층일부,2층~4층,6층 '
# ...

# %%
#문자열을 json으로 변경
json_ob = json.loads(contents)
print(json_ob)
print(type(json_ob)) #json타입 확인
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': 'NORMAL SERVICE.'}, 'body': {'items': {'item': [{'addr': '경기도 안산시 상록구 용신로 352, (본오동, 목화웨딩홀)', 'clCd': 28, 'clCdNm': '요양병원', 'cmdcGdrCnt': 0, 'cmdcIntnCnt': 0, 'cmdcResdntCnt': 0, 'cmdcSdrCnt': 0, 'detyGdrCnt': 0, 'detyIntnCnt': 0, 'detyResdntCnt': 0, 'detySdrCnt': 0, 'drTotCnt': 0, 'estbDd': 20060310, 'mdeptGdrCnt': 0, 'mdeptIntnCnt': 0, 'mdeptResdntCnt': 0, 'mdeptSdrCnt': 0, 'pnursCnt': 0, 'postNo': 15537, 'sgguCd': 311102, 'sgguCdNm': '안산상록구', 'sidoCd': 310000, 'sidoCdNm': '경기', 'telno': '031-363-5200', 'XPos': 126.8611506, 'YPos': 37.3015419, 'yadmNm': '(의)대선의료재단으뜸요양병원', 'ykiho': 'JDQ4MTYyMiM1MSMkMSMkMCMkOTkkNTgxMzUxIzIxIyQyIyQ5IyQwMCQyNjEyMjIjODEjJDEjJDYjJDgz'}, {'addr': '경기도 용인시 수지구 포은대로59번길 17, 광교복합의료센터,지하1층,1층일부,2층~4층,6층 (상현동)', 'clCd': 28, 'clCdNm': '요양병원', 'cmdcGdrCnt': 1, 'cmdcIntnCnt': 0, 'cmdcResdntCnt': 0, 'cmdcSdrCnt': 1, 'detyGdrCnt': 0, 'detyIntnCnt': 0, 'detyResdntCnt': 0, 'detySdrCnt': 0, 'drTotCnt': 6, 'estb
# ...

# %%
# 필요한 내용만 꺼내기
body = json_ob['response']['body']['items']
print(body)
# Out:
# {'item': [{'addr': '경기도 안산시 상록구 용신로 352, (본오동, 목화웨딩홀)', 'clCd': 28, 'clCdNm': '요양병원', 'cmdcGdrCnt': 0, 'cmdcIntnCnt': 0, 'cmdcResdntCnt': 0, 'cmdcSdrCnt': 0, 'detyGdrCnt': 0, 'detyIntnCnt': 0, 'detyResdntCnt': 0, 'detySdrCnt': 0, 'drTotCnt': 0, 'estbDd': 20060310, 'mdeptGdrCnt': 0, 'mdeptIntnCnt': 0, 'mdeptResdntCnt': 0, 'mdeptSdrCnt': 0, 'pnursCnt': 0, 'postNo': 15537, 'sgguCd': 311102, 'sgguCdNm': '안산상록구', 'sidoCd': 310000, 'sidoCdNm': '경기', 'telno': '031-363-5200', 'XPos': 126.8611506, 'YPos': 37.3015419, 'yadmNm': '(의)대선의료재단으뜸요양병원', 'ykiho': 'JDQ4MTYyMiM1MSMkMSMkMCMkOTkkNTgxMzUxIzIxIyQyIyQ5IyQwMCQyNjEyMjIjODEjJDEjJDYjJDgz'}, {'addr': '경기도 용인시 수지구 포은대로59번길 17, 광교복합의료센터,지하1층,1층일부,2층~4층,6층 (상현동)', 'clCd': 28, 'clCdNm': '요양병원', 'cmdcGdrCnt': 1, 'cmdcIntnCnt': 0, 'cmdcResdntCnt': 0, 'cmdcSdrCnt': 1, 'detyGdrCnt': 0, 'detyIntnCnt': 0, 'detyResdntCnt': 0, 'detySdrCnt': 0, 'drTotCnt': 6, 'estbDd': 20180425, 'mdeptGdrCnt': 0, 'mdeptIntnCnt': 0, 'mdeptResdntCnt': 0, 'mdeptSdrCnt': 4, 'pnur
# ...

# %%
# pandas import
import pandas as pd
from pandas.io.json import json_normalize

# Dataframe으로 만들기
dataframe = json_normalize(body)

print(dataframe)
# Out:
#                                                 item
# 0  [{'addr': '경기도 안산시 상록구 용신로 352, (본오동, 목화웨딩홀)',...

# %%
dataframe
# Out:
#                                                 item
# 0  [{'addr': '경기도 안산시 상록구 용신로 352, (본오동, 목화웨딩홀)',...
